# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('lemonade.csv')

# %%
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0      1/1/17     Sunday         27.0      2.00      15    0.5     10
# 1      1/2/17     Monday         28.9      1.33      15    0.5     13
# 2      1/3/17    Tuesday         34.5      1.33      27    0.5     15
# 3      1/4/17  Wednesday         44.1      1.05      28    0.5     17
# 4      1/5/17   Thursday         42.4      1.00      33    0.5     18
# 5      1/6/17     Friday         25.3      1.54      23    0.5     11
# 6      1/7/17   Saturday         32.9      1.54      19    0.5     13
# 7      1/8/17     Sunday         37.5      1.18      28    0.5     15
# 8      1/9/17     Monday         38.1      1.18      20    0.5     17
# 9     1/10/17    Tuesday         43.4      1.05      33    0.5     18
# 10    1/11/17  Wednesday         32.6      1.54      23    0.5     12
# 11    1/12/17   Thursday         38.2      1.33      16    0.5     14
# ...

# %%
q1 = df.quantile(.25)
q3 = df.quantile(.75)
iqr = q3 - q1
lower_mild_outlier = q1- 1.5* iqr
lower_wild_outlier = q1- 3* iqr
upper_mild_outlier = q3 + 1.5* iqr
upper_wild_outlier = q3 + 3 * iqr

# %%
df[(df.Flyers < lower_mild_outlier.Flyers) | (df.Flyers > upper_mild_outlier.Flyers)]
# Out:
#          Date      Day  Temperature  Rainfall  Flyers  Price  Sales
# 166   6/16/17   Friday         99.3      0.47      77    0.5     41
# 194   7/14/17   Friday         92.0      0.50      80    0.5     40
# 324  11/21/17  Tuesday         47.0      0.95     -38    0.5     20

# %%
df['outliers'] = (df.Flyers < lower_mild_outlier.Flyers) | (df.Flyers > upper_mild_outlier.Flyers)
sns.scatterplot(data=df,x='Temperature',y='Sales',hue='outliers')

# %%
sns.scatterplot(data=df,x='Temperature',y='Sales',hue='outliers')

# %%
#print("Lower outlier: \n", lower_mild_outlier)
#print(lower_wild_outlier)
#print("Upper Outlier: \n", upper_mild_outlier)
#print(upper_wild_outlier)
df.head()
# Out:
#      Date        Day  Temperature  Rainfall  Flyers  Price  Sales  outliers
# 0  1/1/17     Sunday         27.0      2.00      15    0.5     10     False
# 1  1/2/17     Monday         28.9      1.33      15    0.5     13     False
# 2  1/3/17    Tuesday         34.5      1.33      27    0.5     15     False
# 3  1/4/17  Wednesday         44.1      1.05      28    0.5     17     False
# 4  1/5/17   Thursday         42.4      1.00      33    0.5     18     False

# %%
df.describe().T
# Out:
#              count       mean        std   min    25%    50%    75%    max
# Temperature  365.0  61.224658  18.085892  15.1  49.70  61.10  71.70  212.0
# Rainfall     365.0   0.825973   0.273890   0.4   0.65   0.74   0.91    2.5
# Flyers       365.0  40.104110  13.786445 -38.0  31.00  39.00  49.00   80.0
# Price        365.0   0.500000   0.000000   0.5   0.50   0.50   0.50    0.5
# Sales        365.0  27.589041  29.979680   7.0  20.00  25.00  30.00  534.0

# %%
print("Lower outlier: \n", lower_wild_outlier)
#print(lower_wild_outlier)
print("Upper Outlier: \n", upper_wild_outlier)
#print(upper_wild_outlier)
# Out:
# Lower outlier:
#  Temperature   -16.30
# Rainfall       -0.13
# Flyers        -23.00
# Price           0.50
# Sales         -10.00
# dtype: float64
# Upper Outlier:
#  Temperature    137.70
# Rainfall         1.69
# Flyers         103.00
# Price            0.50
# Sales           60.00
# dtype: float64

# %%
df.dtypes
# Out:
# Date            object
# Day             object
# Temperature    float64
# Rainfall       float64
# Flyers           int64
# Price          float64
# Sales            int64
# dtype: object

# %%
df_dist = df.drop(columns=['Date','Day'])

# %%
df_dist.drop(columns='Price',inplace=True)

# %%
# fig, axes = plt.subplots(nrows=2,ncols=2)
# ax = axes[2,2]

# for i,column in enumerate(df_dist.columns):
#     sns.distplot(df_dist[column],ax=axes[i//2,i%2])

# %%
sns.distplot(df_dist.Temperature)

# %%
sns.distplot(df_dist.Rainfall)

# %%
sns.distplot(df_dist.Flyers)

# %%
sns.distplot(df_dist.Sales)

# %%
df.dtypes
# Out:
# Date            object
# Day             object
# Temperature    float64
# Rainfall       float64
# Flyers           int64
# Price          float64
# Sales            int64
# dtype: object

# %%
df_test = df[['Temperature','Rainfall','Flyers','Price','Sales']].subtract(df.mean())

# %%
df.shape
# Out:
# (365, 7)

# %%
df_test.shape
# Out:
# (365, 5)

# %%
rainfall = df.Rainfall.mean()

# %%
2 - rainfall
# Out:
# 1.1740273972602733

# %%
df_z = pd.concat([df[['Date','Day']],df_test],axis = 1)

# %%
df_z = df_test /df_test.std()

# %%
df_test[df_z.abs() >2]
# Out:
#      Temperature  Rainfall    Flyers  Price  Sales
# 0            NaN  1.174027       NaN    NaN    NaN
# 1            NaN       NaN       NaN    NaN    NaN
# 2            NaN       NaN       NaN    NaN    NaN
# 3            NaN       NaN       NaN    NaN    NaN
# 4            NaN       NaN       NaN    NaN    NaN
# 5            NaN  0.714027       NaN    NaN    NaN
# 6            NaN  0.714027       NaN    NaN    NaN
# 7            NaN       NaN       NaN    NaN    NaN
# 8            NaN       NaN       NaN    NaN    NaN
# 9            NaN       NaN       NaN    NaN    NaN
# 10           NaN  0.714027       NaN    NaN    NaN
# 11           NaN       NaN       NaN    NaN    NaN
# 12           NaN       NaN       NaN    NaN    NaN
# 13           NaN       NaN       NaN    NaN    NaN
# 14           NaN       NaN       NaN    NaN    NaN
# 15           NaN  0.844027       NaN    NaN    NaN
# 16           NaN  0.604027       NaN    NaN    NaN
# ...

# %%
df_test.head(2)
# Out:
#    Temperature  Rainfall    Flyers  Price      Sales
# 0   -34.224658  1.174027 -25.10411    0.0 -17.589041
# 1   -32.324658  0.504027 -25.10411    0.0 -14.589041

# %%
df.describe().T
# Out:
#              count       mean        std   min    25%    50%    75%    max
# Temperature  365.0  61.224658  18.085892  15.1  49.70  61.10  71.70  212.0
# Rainfall     365.0   0.825973   0.273890   0.4   0.65   0.74   0.91    2.5
# Flyers       365.0  40.104110  13.786445 -38.0  31.00  39.00  49.00   80.0
# Price        365.0   0.500000   0.000000   0.5   0.50   0.50   0.50    0.5
# Sales        365.0  27.589041  29.979680   7.0  20.00  25.00  30.00  534.0

# %%
df.describe().T
# Out:
#              count       mean        std   min    25%    50%    75%    max
# Temperature  365.0  61.224658  18.085892  15.1  49.70  61.10  71.70  212.0
# Rainfall     365.0   0.825973   0.273890   0.4   0.65   0.74   0.91    2.5
# Flyers       365.0  40.104110  13.786445 -38.0  31.00  39.00  49.00   80.0
# Price        365.0   0.500000   0.000000   0.5   0.50   0.50   0.50    0.5
# Sales        365.0  27.589041  29.979680   7.0  20.00  25.00  30.00  534.0

# %%
df.sort_values(by='Temperature',ascending=False)
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 41    2/11/17   Saturday        212.0      0.91      35    0.5     21
# 181    7/1/17   Saturday        102.9      0.47      59    0.5     43
# 176   6/26/17     Monday        102.6      0.47      60    0.5     42
# 202   7/22/17   Saturday         99.6      0.47      49    0.5     42
# 198   7/18/17    Tuesday         99.3      0.47      76    0.5     41
# 166   6/16/17     Friday         99.3      0.47      77    0.5     41
# 190   7/10/17     Monday         98.0      0.49      66    0.5     40
# 207   7/27/17   Thursday         97.9      0.47      74    0.5     43
# 171   6/21/17  Wednesday         94.3      0.47      76    0.5     41
# 182    7/2/17     Sunday         93.4      0.51      68    0.5     38
# 185    7/5/17  Wednesday         93.0      0.40      55    0.5     99
# 162   6/12/17     Monday         93.0      0.50      67    0.5     40
# ...

# %%
df.nunique()
# Out:
# Date           365
# Day              7
# Temperature    176
# Rainfall        35
# Flyers          63
# Price            1
# Sales           39
# dtype: int64

# %%
df.sort_values(by='Sales',ascending=False)
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 184    7/4/17    Tuesday         84.2      0.59      49    0.5    534
# 183    7/3/17     Monday         81.5      0.54      68    0.5    235
# 185    7/5/17  Wednesday         93.0      0.40      55    0.5     99
# 258   9/16/17   Saturday         68.1      0.69      37    0.5     87
# 181    7/1/17   Saturday        102.9      0.47      59    0.5     43
# 207   7/27/17   Thursday         97.9      0.47      74    0.5     43
# 176   6/26/17     Monday        102.6      0.47      60    0.5     42
# 202   7/22/17   Saturday         99.6      0.47      49    0.5     42
# 198   7/18/17    Tuesday         99.3      0.47      76    0.5     41
# 166   6/16/17     Friday         99.3      0.47      77    0.5     41
# 171   6/21/17  Wednesday         94.3      0.47      76    0.5     41
# 162   6/12/17     Monday         93.0      0.50      67    0.5     40
# ...

# %%
sns.scatterplot(x=df.Date,y=df.Rainfall).set_title("Rainfall over time")
# Out:
# Text(0.5, 1.0, 'Rainfall over time')

# %%
sns.scatterplot(x=df.Date,y=df.Sales).set_title("Rainfall over time")
# Out:
# Text(0.5, 1.0, 'Rainfall over time')

# %%
df.head(2)
# Out:
#      Date     Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  1/1/17  Sunday         27.0      2.00      15    0.5     10
# 1  1/2/17  Monday         28.9      1.33      15    0.5     13

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df = df.set_index('Date')

# %%
df.head(2)
# Out:
#                Day  Temperature  Rainfall  Flyers  Price  Sales
# Date
# 2017-01-01  Sunday         27.0      2.00      15    0.5     10
# 2017-01-02  Monday         28.9      1.33      15    0.5     13

# %%
df.resample('W').mean()

sns.scatterplot(x=df.Date,y=df.Sales).set_title("Rainfall over time")
# Out:
#             Temperature  Rainfall     Flyers  Price       Sales
# Date
# 2017-01-01    27.000000  2.000000  15.000000    0.5   10.000000
# 2017-01-08    35.085714  1.281429  24.714286    0.5   14.571429
# 2017-01-15    39.614286  1.227143  23.857143    0.5   15.857143
# 2017-01-22    36.757143  1.321429  24.000000    0.5   14.428571
# 2017-01-29    35.271429  1.257143  21.000000    0.5   14.714286
# 2017-02-05    46.885714  0.987143  31.000000    0.5   19.142857
# 2017-02-12    72.885714  0.905714  36.142857    0.5   20.714286
# 2017-02-19    46.785714  0.962857  30.714286    0.5   19.285714
# 2017-02-26    46.257143  0.974286  28.714286    0.5   19.428571
# 2017-03-05    55.042857  0.855714  35.000000    0.5   23.000000
# 2017-03-12    58.814286  0.787143  34.285714    0.5   24.142857
# 2017-03-19    56.928571  0.832857  38.857143    0.5   23.571429
# 2017-03-26    57.485714  0.801429  38.857143    0.5   24.000000
# 2017-04-02    58.657143  0.787143  41.714286    0.5   24.571429
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-101-2662c7f79d0a> in <module>
# ----> 1 import Datetime as dt
#
# ModuleNotFoundError: No module named 'Datetime'

# %%
df['week_day'] = df.index.strftime('%w-%a')

# %%
df.head()
# Out:
#                   Day  Temperature  Rainfall  Flyers  Price  Sales week_day
# Date
# 2017-01-01     Sunday         27.0      2.00      15    0.5     10    0-Sun
# 2017-01-02     Monday         28.9      1.33      15    0.5     13    1-Mon
# 2017-01-03    Tuesday         34.5      1.33      27    0.5     15    2-Tue
# 2017-01-04  Wednesday         44.1      1.05      28    0.5     17    3-Wed
# 2017-01-05   Thursday         42.4      1.00      33    0.5     18    4-Thu

# %%
def all_box_plots(df):
    new_df = df.copy()
    new_df = new_df.sort_values(by='week_day')
    for col in df_limit_numerics(df).columns:
        
        plt.figure(figsize=(7,5))
        sns.boxplot(data=new_df,x='week_day',y=col,showmeans=True)

        plt.hlines(df[col].mean(),0,6, color='limegreen')
        plt
        plt.ylabel(col)
        plt.show()

# %%
sns.boxplot(data=df_sales,x='week_day',y='Sales')

# %%
df_sales = df[df.Sales < 80]

# %%
df.sort_values(by='Temperature',ascending=False).head(1)
# Out:
#        Date       Day  Temperature  Rainfall  Flyers  Price  Sales
# 41  2/11/17  Saturday        212.0      0.91      35    0.5     21

# %%
df.Temperature = np.where(df.Temperature == 212,200,df.Temperature)
df.sort_values(by='Temperature',ascending=False).head(1)
# Out:
#        Date       Day  Temperature  Rainfall  Flyers  Price  Sales
# 41  2/11/17  Saturday        200.0      0.91      35    0.5     21

# %%
# Out:
#                   Day  Temperature  Rainfall  Flyers  Price  Sales week_day
# Date
# 2017-02-11   Saturday        200.0      0.91      35    0.5     21    6-Sat
# 2017-07-01   Saturday        102.9      0.47      59    0.5     43    6-Sat
# 2017-06-26     Monday        102.6      0.47      60    0.5     42    1-Mon
# 2017-07-22   Saturday         99.6      0.47      49    0.5     42    6-Sat
# 2017-07-18    Tuesday         99.3      0.47      76    0.5     41    2-Tue
# 2017-06-16     Friday         99.3      0.47      77    0.5     41    5-Fri
# 2017-07-10     Monday         98.0      0.49      66    0.5     40    1-Mon
# 2017-07-27   Thursday         97.9      0.47      74    0.5     43    4-Thu
# 2017-06-21  Wednesday         94.3      0.47      76    0.5     41    3-Wed
# 2017-07-02     Sunday         93.4      0.51      68    0.5     38    0-Sun
# 2017-07-05  Wednesday         93.0      0.40      55    0.5     99    3-Wed
# ...
