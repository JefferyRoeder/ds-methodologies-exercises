# %%
from __future__ import division
import itertools
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import math
from sklearn import metrics
from random import randint
from matplotlib import style
import seaborn as sns
# %matplotlib inline

import bs4 as bs
import urllib.request
import csv
import pandas as pd
import time

# %%
colnames=['ip', 'timestamp', 'request_method', 'status', 'size',
          'destination', 'request_agent']
df_orig = pd.read_csv('http://python.zach.lol/access.log',          
                 engine='python',
                 header=None,
                 index_col=False,
                 names=colnames,
                 sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                 na_values='"-"',
                 usecols=[0, 3, 4, 5, 6, 7, 8])

# %%
df_orig.head(2)
# Out:
#              ip                     timestamp  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 1  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
#
#                          request_method  status    size destination  \
# 0  "GET /api/v1/sales?page=81 HTTP/1.1"     200  512495         NaN
# 1          "GET /api/v1/items HTTP/1.1"     200    3561         NaN
#
#               request_agent
# 0  "python-requests/2.21.0"
# 1  "python-requests/2.21.0"

# %%
new = pd.DataFrame([["95.31.18.119", "[21/Apr/2019:10:02:41+0000]", 
                     "GET /api/v1/items/HTTP/1.1", 200, 1153005, np.nan, 
                     "python-requests/2.21.0"],
                    ["95.31.16.121", "[17/Apr/2019:19:36:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 301, 1005, np.nan, 
                     "python-requests/2.21.0"],
                    ["97.105.15.120", "[18/Apr/2019:19:42:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 301, 2560, np.nan, 
                     "python-requests/2.21.0"],
                    ["97.105.19.58", "[19/Apr/2019:19:42:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 200, 2056327, np.nan, 
                     "python-requests/2.21.0"]], columns=colnames)

df = df_orig.append(new)

# %%
df.head(3)
# Out:
#              ip                     timestamp  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 1  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 2  97.105.19.58  [16/Apr/2019:19:34:44 +0000]
#
#                          request_method  status    size destination  \
# 0  "GET /api/v1/sales?page=81 HTTP/1.1"     200  512495         NaN
# 1          "GET /api/v1/items HTTP/1.1"     200    3561         NaN
# 2  "GET /api/v1/sales?page=82 HTTP/1.1"     200  510103         NaN
#
#               request_agent
# 0  "python-requests/2.21.0"
# 1  "python-requests/2.21.0"
# 2  "python-requests/2.21.0"

# %%
#unique values by column
type(df.ip.unique())

# %%
# one off requests
df.groupby('request_method')['request_method'].count().sort_values().head(15)

# %%
# frequency of IPs
df_ip_unique = df.groupby('ip')['ip'].count().sort_values(ascending=False).tail(18)

# %%
df_ip_unique.index
# Out:
# Index(['68.201.219.223', '24.26.242.9', '52.87.230.102', '35.175.171.137',
#        '70.121.214.34', '3.88.129.158', '3.92.201.136', '34.207.64.242',
#        '34.229.70.250', '35.174.209.2', '95.31.18.119', '45.23.250.16',
#        '95.31.16.121', '97.105.15.120', '52.91.30.150', '54.145.52.184',
#        '54.172.14.223', '52.90.165.200'],
#       dtype='object', name='ip')

# %%
#52.87.230.102, 35.175.171.137 3.88.129.158, 3.92.201.136, 34.207.64.242 
# 34.229.70.250, 35.174.209.2, 52.91.30.150, 54.145.52.184
#coming from Virginia, Amazon.com

# 45.23.250.16 New Braunfels

# %% [markdown]
# #### 95.31.16.121 Moscow. HTTP 301 request to redirect URL

# %% [markdown]
# <img src="russia.png" alt="Drawing" style="width: 350px;"/>

# %%
df[df.ip == '95.31.16.121']
# Out:
#              ip                    timestamp  \
# 1  95.31.16.121  [17/Apr/2019:19:36:41+0000]
#
#                        request_method  status  size destination  \
# 1  GET /api/v1/sales?page=79/HTTP/1.1     301  1005         NaN
#
#             request_agent
# 1  python-requests/2.21.0

# %%
source = urllib.request.urlopen('https://www.ip-tracker.org').read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
ip_list = df.ip.unique())
table = soup.find_all("table",{"class":"table_dark_green"})

# %%
ip_list
for i in ip_list_short:
    source = f'https://www.melissa.com/v2/lookups/iplocation/ip/?ip={i}&site='

# %%
table = soup.find(id='tableInfo50')

# %%
ip_list_short

# %%
#rows = table.findChildren(['tr'])
ip_data = []

# %%
ip_data = []
for i in ip_list_short:
    source = f'https://www.melissa.com/v2/lookups/iplocation/ip/?ip={i}'
    soup = bs.BeautifulSoup(source,'lxml')
    table = soup.find(id='tableInfo50')
    rows = table.findChildren(['tr'])
    for row in rows:
        values = []
        cells = row.findChildren('td')
        for cell in cells:
            value = cell.string
            values.append(value)
        ip_data.append(values[1])
        #print(values[1])
        #country =
       # region = 

    #     isp = 
    #     lat =
    #     long =
    #     org =

    # for t in table:
    #     rating = t.select('span',{"class":"num"})
    #     name = t.select('a',{"class":"name"})
    #     brewery = t.select('a',{"class":"style"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-dd2f215bf8f7> in <module>
#       4     soup = bs.BeautifulSoup(source,'lxml')
#       5     table = soup.find(id='tableInfo50')
# ----> 6     rows = table.findChildren(['tr'])
#       7     for row in rows:
#       8         values = []
#
# AttributeError: 'NoneType' object has no attribute 'findChildren'

# %%
source = 'https://www.melissa.com/v2/lookups/iplocation/ip/?ip=97.105.19.58&site='
soup = bs.BeautifulSoup(source,'lxml')
table = soup.find(id='content')
#rows = table.findChildren(['tr'])
p
# Out:
# None

# %%
soup.find_all('table')
print(soup)
# Out:
# <html><body><p>https://www.melissa.com/v2/lookups/iplocation/ip/?ip=3.92.201.136&amp;site=</p></body></html>

# %%
soup.find('')

# %%
df.describe()
# Out:
#              status          size
# count  13978.000000  1.397800e+04
# mean     200.356703  4.500019e+05
# std       10.182001  1.614915e+05
# min      200.000000  0.000000e+00
# 25%      200.000000  5.006370e+05
# 50%      200.000000  5.101380e+05
# 75%      200.000000  5.112910e+05
# max      499.000000  2.056327e+06

# %%
df.dtypes
# Out:
# ip                object
# timestamp         object
# request_method    object
# status             int64
# size               int64
# destination       object
# request_agent     object
# dtype: object

# %%
df.nunique()
# Out:
# ip                  22
# timestamp         9957
# request_method     220
# status               3
# size               191
# destination         18
# request_agent       10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13978 entries, 0 to 3
# Data columns (total 7 columns):
# ip                13978 non-null object
# timestamp         13978 non-null object
# request_method    13978 non-null object
# status            13978 non-null int64
# size              13978 non-null int64
# destination       25 non-null object
# request_agent     13978 non-null object
# dtypes: int64(2), object(5)
# memory usage: 873.6+ KB

# %%
df
# Out:
#                   ip                     timestamp  \
# 0       97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 1       97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 2       97.105.19.58  [16/Apr/2019:19:34:44 +0000]
# 3       97.105.19.58  [16/Apr/2019:19:34:46 +0000]
# 4       97.105.19.58  [16/Apr/2019:19:34:48 +0000]
# 5       97.105.19.58  [16/Apr/2019:19:34:48 +0000]
# 6       97.105.19.58  [16/Apr/2019:19:34:50 +0000]
# 7       97.105.19.58  [16/Apr/2019:19:34:52 +0000]
# 8       97.105.19.58  [16/Apr/2019:19:34:52 +0000]
# 9       97.105.19.58  [16/Apr/2019:19:34:53 +0000]
# 10      97.105.19.58  [16/Apr/2019:19:34:53 +0000]
# 11      97.105.19.58  [16/Apr/2019:19:34:53 +0000]
# 12      97.105.19.58  [16/Apr/2019:19:34:54 +0000]
# 13      97.105.19.58  [16/Apr/2019:19:34:54 +0000]
# 14      97.105.19.58  [16/Apr/2019:19:34:56 +0000]
# 15      97.105.19.58  [16/Apr/2019:19:34:58 +0000]
# 16      97.105.19.58  [16/Apr/2019:19:35:01 +0000]
# ...
