# %%
import pandas as pd
import numpy as np
from pydataset import data
import pyspark
import matplotlib.pyplot as plt

from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import concat, col, sum, avg, min, max, mean, count
from pyspark.sql.functions import to_date
from pyspark.sql.functions import *
import wrangle

# %%
df = wrangle.wrangle_311()

# %%
df.show(1,vertical=True)
# Out:
# -RECORD 0------------------------------------
#  dept_division        | Field Operations
#  case_id              | 1014127332
#  case_late            | NO
#  num_days_late        | -998.5087616000001
#  service_request_type | Stray Animal
#  SLA_days             | 999.0
#  case_status          | Closed
#  source_id            | svcCRMLS
#  request_address      | 2315  EL PASO ST,...
#  council_district     | 5
#  case_open_date       | 2018-01-01
#  case_close_date      | 2018-01-01
#  case_due_date        | 2020-09-26
#  council_district     | 5
#  year_closed          | 2018
#  dept_div             | Field Operations
#  dept_name            | Animal Care Services
#  id                   | svcCRMLS
#  source_username      | svcCRMLS
# only showing top 1 row

# %%
count_by_div = df.groupBy('dept_division').count().toPandas()

# %%
count_by_div.set_index('dept_division',inplace=True)

# %%
count_by_div.plot()
plt.xticks(rotation=45)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  <a list of 9 Text xticklabel objects>)
