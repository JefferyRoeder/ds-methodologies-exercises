# %%
import pandas as pd
import numpy as np
import env
import wrangle
import acquire
import seaborn as sns
import prep

# %%
df = acquire.single_unit_properties()

# %%
#df['transactiondate'] = pd.to_datetime(df['transactiondate'])
#df2 = acquire.prep_properties()

# %%
#df = df[df.groupby('parcelid')['transactiondate'].transform('max') ==df['transactiondate']]

# %%
df.head().transpose()

# %%
#df_all = pd.merge(df2,df,on='parcelid',how='left')

# %%
df.describe().transpose()

# %%
df.shape

# %%
df = prep.drop_columns(df)
df = prep.drop_rows(df)

# %%
df = df.drop(columns=['id','calculatedbathnbr','finishedsquarefeet12','fullbathcnt','rawcensustractandblock','roomcnt'])

# %%
sns.pairplot(df)

# %%
df_nulls_c.sort_values(by='pct_rows_missing',ascending=False)

# %%
df.shape

# %%
df_nulls_r = pd.DataFrame(df_new.apply(lambda x: df_new.shape[1] -x.count(),axis=1))
df_nulls_r['pct_rows_missing'] = df_nulls_r[0] / df_new.shape[1]
row_drops = df_nulls_r[df_nulls_r['pct_rows_missing'] >.6]
row_drops['column_names'] = row_drops.index
row_drops = list(row_drops.column_names)
df_new = df_new.drop(row_drops,axis=0)
df_new.shape

# %%
df_nulls_r = pd.DataFrame(df.apply(lambda x: len(x) - x.count(),axis=1))
df_nulls_r['pct_rows_missing'] = df_nulls_r[0] / len(df)

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan,strategy ='mode')

# %%
sns.pairplot(df)
